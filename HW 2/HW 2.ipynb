# %%
# imports

import csv
import matplotlib.pyplot as plt
import numpy as np

# %%
import csv

t = [] # column 0
data1 = [] # column 1
data2 = [] # column 2

with open('sigA.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

print(len(data1))
# for i in range(len(t)):
#     # print the data to verify it was read
#     print(str(t[i]) + ", " + str(data1[i]))
# Out:
# 50000

# %%
import matplotlib.pyplot as plt
plt.plot(t, data1)

# %%
# find sample rate
samplerate = len(data1)/t[-1]
print(samplerate)
# Out:
# 10000.20000400008

# %%
# FFT for sigA

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(t,y,'b')
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax2.loglog(frq,abs(Y),'b') # plotting the fft
ax2.set_xlabel('Freq (Hz)')
ax2.set_ylabel('|Y(freq)|')
plt.show()

# %%
# FFT for sigA

t = [] # column 0
data1 = [] # column 1
data2 = [] # column 2

with open('sigA.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

plt.plot(t, data1)

samplerate = len(data1)/t[-1]
print(samplerate)

# FFT for sigA

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(t,y,'b')
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax2.loglog(frq,abs(Y),'b') # plotting the fft
ax2.set_xlabel('Freq (Hz)')
ax2.set_ylabel('|Y(freq)|')
plt.show()
# Out:
# 10000.20000400008

# %%
# FFT for sigB

t = [] # column 0
data1 = [] # column 1
data2 = [] # column 2

with open('sigB.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

plt.plot(t, data1)

samplerate = len(data1)/t[-1]
print(samplerate)

# FFT for sigA

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(t,y,'b')
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax2.loglog(frq,abs(Y),'b') # plotting the fft
ax2.set_xlabel('Freq (Hz)')
ax2.set_ylabel('|Y(freq)|')
plt.show()
# Out:
# 3300.2000121219467

# %%
# FFT for sigC

t = [] # column 0
data1 = [] # column 1
data2 = [] # column 2

with open('sigC.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

plt.plot(t, data1)

samplerate = len(data1)/t[-1]
print(samplerate)

# FFT for sigA

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(t,y,'b')
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax2.loglog(frq,abs(Y),'b') # plotting the fft
ax2.set_xlabel('Freq (Hz)')
ax2.set_ylabel('|Y(freq)|')
plt.show()
# Out:
# 2500.1250062503127

# %%
# FFT for sigD

t = [] # column 0
data1 = [] # column 1
data2 = [] # column 2

with open('sigD.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

plt.plot(t, data1)

samplerate = len(data1)/t[-1]
print(samplerate)

# FFT for sigA

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]

fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(t,y,'b')
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax2.loglog(frq,abs(Y),'b') # plotting the fft
ax2.set_xlabel('Freq (Hz)')
ax2.set_ylabel('|Y(freq)|')
plt.show()
# Out:
# 400.0833506980621

# %%
# Low pass filter sigA

t = [] # column 0
data1 = [] # column 1

with open('sigA.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

data = data1.copy()
x = 10000
newdata = []

for i in range(x):
    data.insert(i, 0)
for j in range(len(data)-x):
    sum = 0
    for i in range(x): 
        sum = sum + data[j + x - i]
    avg = sum/x
    newdata.append(avg)

samplerate = len(data)/t[-1]
newsamplerate = len(newdata)/t[-1]


# FFT for sigA

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'black') # plotting the fft
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')


# plotting the new sample FFT
samplerate = len(newdata)/t[-1]

# FFT for sigA

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'red') # plotting the fft
plt.title('FFT plot of sigA with 10,000 points averaged')
plt.show()

# %%
# Low pass filter sigB

t = [] # column 0
data1 = [] # column 1

with open('sigB.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

data = data1.copy()
x = 1000
newdata = []

for i in range(x):
    data.insert(i, 0)
for j in range(len(data)-x):
    sum = 0
    for i in range(x): 
        sum = sum + data[j + x - i]
    avg = sum/x
    newdata.append(avg)

samplerate = len(data)/t[-1]
newsamplerate = len(newdata)/t[-1]


# FFT for sigB

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'black') # plotting the fft
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')


# plotting the new sample FFT
samplerate = len(newdata)/t[-1]

# FFT for sigB

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'red') # plotting the fft
plt.title('FFT plot of sigB with 1000 points averaged')
plt.show()

# %%
# Low pass filter sigC 

t = [] # column 0
data1 = [] # column 1

with open('sigC.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

data = data1.copy()
x = 1000
newdata = []

for i in range(x):
    data.insert(i, 0)
for j in range(len(data)-x):
    sum = 0
    for i in range(x): 
        sum = sum + data[j + x - i]
    avg = sum/x
    newdata.append(avg)

samplerate = len(data)/t[-1]
newsamplerate = len(newdata)/t[-1]


# FFT for sigC

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'black') # plotting the fft
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')


# plotting the new sample FFT
samplerate = len(newdata)/t[-1]

# FFT for sigC

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'red') # plotting the fft
plt.title('FFT plot of sigC with 1000 points averaged')
plt.show()

# %%
# Low pass filter sigD

t = [] # column 0
data1 = [] # column 1

with open('sigD.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

data = data1.copy()
x = 1000
newdata = []

for i in range(x):
    data.insert(i, 0)
for j in range(len(data)-x):
    sum = 0
    for i in range(x): 
        sum = sum + data[j + x - i]
    avg = sum/x
    newdata.append(avg)

samplerate = len(data)/t[-1]
newsamplerate = len(newdata)/t[-1]


# FFT for sigD

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'black') # plotting the fft
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')


# plotting the new sample FFT
samplerate = len(newdata)/t[-1]

# FFT for sigD

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'red') # plotting the fft
plt.title('FFT plot of sigD with 1000 points averaged')
plt.show()

# %%
# Low pass filtering with an IIR for sigA

t = [] # column 0
data1 = [] # column 1

with open('sigA.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

data = data1.copy()
A = 0.9999
B = 1-A
newdata = []
newdata.append(data[0])

for i in range(1, len(data)):
    newdata.append(A*newdata[i-1] + B*data[i])

samplerate = len(data)/t[-1]
newsamplerate = len(newdata)/t[-1]


# FFT for sigA

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'black') # plotting the fft
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')


# plotting the new sample FFT
samplerate = len(newdata)/t[-1]

# FFT for sigA

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'red') # plotting the fft
plt.title('FFT plot of sigA with A = ' + str(A) + ' and B = '+ str(B)+ '')
plt.show()

# %%
# Low pass filtering with an IIR for sigB

t = [] # column 0
data1 = [] # column 1

with open('sigB.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

data = data1.copy()
A = 0.9999
B = 1-A
newdata = []
newdata.append(data[0])

for i in range(1, len(data)):
    newdata.append(A*newdata[i-1] + B*data[i])

samplerate = len(data)/t[-1]
newsamplerate = len(newdata)/t[-1]


# FFT for sigB

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'black') # plotting the fft
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')


# plotting the new sample FFT
samplerate = len(newdata)/t[-1]

# FFT for sigB

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'red') # plotting the fft
plt.title('FFT plot of sigA with A = ' + str(A) + ' and B = '+ str(B)+ '')
plt.show()

# %%
# Low pass filtering with an IIR for sigC

t = [] # column 0
data1 = [] # column 1

with open('sigC.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

data = data1.copy()
A = 0.99
B = 1-A
newdata = []
newdata.append(data[0])

for i in range(1, len(data)):
    newdata.append(A*newdata[i-1] + B*data[i])

samplerate = len(data)/t[-1]
newsamplerate = len(newdata)/t[-1]


# FFT for sigC

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'black') # plotting the fft
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')


# plotting the new sample FFT
samplerate = len(newdata)/t[-1]

# FFT for sigC

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'red') # plotting the fft
plt.title('FFT plot of sigA with A = ' + str(A) + ' and B = '+ str(B)+ '')
plt.show()

# %%
# Low pass filtering with an IIR for sigD

t = [] # column 0
data1 = [] # column 1

with open('sigD.csv') as f:
    # open the csv file
    reader = csv.reader(f)
    for row in reader:
        # read the rows 1 one by one
        t.append(float(row[0])) # leftmost column
        data1.append(float(row[1])) # second column

data = data1.copy()
A = 0.99
B = 1-A
newdata = []
newdata.append(data[0])

for i in range(1, len(data)):
    newdata.append(A*newdata[i-1] + B*data[i])

samplerate = len(data)/t[-1]
newsamplerate = len(newdata)/t[-1]


# FFT for sigD

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = data1 # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'black') # plotting the fft
plt.xlabel('Freq (Hz)')
plt.ylabel('|Y(freq)|')


# plotting the new sample FFT
samplerate = len(newdata)/t[-1]

# FFT for sigD

Fs = samplerate # sample rate
Ts = 1.0/Fs; # sampling interval
ts = np.arange(0,t[-1],Ts) # time vector
y = newdata # the data to make the fft from
n = len(y) # length of the signal
k = np.arange(n)
T = n/Fs
frq = k/T # two sides frequency range
frq = frq[range(int(n/2))] # one side frequency range
Y = np.fft.fft(y)/n # fft computing and normalization
Y = Y[range(int(n/2))]


plt.loglog(frq,abs(Y),'red') # plotting the fft
plt.title('FFT plot of sigA with A = ' + str(A) + ' and B = '+ str(B)+ '')
plt.show()
